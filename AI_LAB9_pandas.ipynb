# %%
import pandas as pd
data = pd.DataFrame({'Country':['Pakistan','Russia','India','Cuba'],'Rank':[212,122,342,412]})
data
# Out:
#     Country  Rank
# 0  Pakistan   212
# 1    Russia   122
# 2     India   342
# 3      Cuba   412

# %%
import pandas as pd
data = pd.DataFrame({'Menu':['Pizza','Roll','Burger','Coffee'],'Price':[212,122,342,412]})
data.describe()
# Out:
#             Price
# count    4.000000
# mean   272.000000
# std    129.871732
# min    122.000000
# 25%    189.500000
# 50%    277.000000
# 75%    359.500000
# max    412.000000

# %%
import pandas as pd
data = pd.DataFrame({'Menu':['Pizza','Roll','Burger','Coffee'],'Price':[212,122,342,412]})
data
# data.describe()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Menu    4 non-null      object
#  1   Price   4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
import pandas as pd
data = pd.DataFrame({'Group':['a','a','a','b','b','b','c','c','c'],'ounces':[1,2,3,4,5,6,7,8,9]})
data.sort_values(by=['ounces'],ascending=True,inplace=False)
# Out:
#   Group  ounces
# 0     a       1
# 1     a       2
# 2     a       3
# 3     b       4
# 4     b       5
# 5     b       6
# 6     c       7
# 7     c       8
# 8     c       9

# %%
import pandas as pd
data = pd.DataFrame({'Group':['a','a','a','b','b','b','c','c','c'],'ounces':[1,2,3,4,5,6,7,8,9]})
data.sort_values(by=['Group','ounces'],ascending=True,inplace=False)
# Out:
#   Group  ounces
# 0     a       1
# 1     a       2
# 2     a       3
# 3     b       4
# 4     b       5
# 5     b       6
# 6     c       7
# 7     c       8
# 8     c       9

# %%
import pandas as pd
data = pd.DataFrame({'k1':['one']*3+['two']*4,'k2':[1,2,3,4,4,6,7]})
data.drop_duplicates(subset='k1')
# Out:
#     k1  k2
# 0  one   1
# 3  two   4

# %%
import pandas as pd
data = pd.DataFrame({'Country':['Pakistan','Russia','India','UnitedKingdom'],'Rank':[212,122,342,412]})
data
country_to_continent = {
    'Pakistan':'Asia',
    'Russia':'Russia',
    'India':'Asia',
    'UnitedKingdom':'Europe'
}
def Contenets(series):
  if series==

# %%
import pandas as pd
data = pd.DataFrame({'student': ['Umar','zulqernain','Abdullah','Qasim']})
sap_id={
  'Umar' :31970,
  'Zulqernain':31980,
  'Abdullah':31440,
  'Qasim':31500
}

def student_to_Sap_id(se):
  if se['student']=='Umar':
    return 31970
  elif se['student']=='Zulqernain':
    return 31980
  elif se['student']=='Abdullah':
    return 31440
  elif se['student']=='Qasim':
    return 31500
data['stud']=data['student'].map(sap_id)
data
# Out:
#       student     stud
# 0        Umar  31970.0
# 1  zulqernain      NaN
# 2    Abdullah  31440.0
# 3       Qasim  31500.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['stud'].plot(kind='hist', bins=20, title='stud')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# data.groupby('student').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
data=pd.DataFrame({
    'K1':[123,466,789,789],
    'Name':['Ahmed','Umar','Abdullah','Qasim']
    })
data.drop_duplicates(subset=['K1'])
# Out:
#     K1      Name
# 0  123     Ahmed
# 1  466      Umar
# 2  789  Abdullah

# %%
import pandas as ps
data = ps.DataFrame({
    'Sapid':[31144,12345,54666],
   'Name':['Umar','Abdullah','Umair']})
data.assign(Marks= [100,70,80,])
# Out:
#    Sapid      Name  Marks
# 0  31144      Umar    100
# 1  12345  Abdullah     70
# 2  54666     Umair     80

# %%
import pandas as ps
data = ps.DataFrame({
    'Sapid':[36546,12345,54666],
   'Name':['Umar','Abdullah','Umair']})
data.drop('Sapid',axis='columns',inplace=True)
data
# Out:
#        Name
# 0      Umar
# 1  Abdullah
# 2     Umair

# %%
data = {'Fruits': ['Mango', 'Apple', 'Banana'],
'Rwp': [80, 40, 60],
'Lhr': [100, 30, 90],
'Isb': [90, 50, 100]}
data
# Out:
# {'Fruits': ['Mango', 'Apple', 'Banana'],
#  'Rwp': [80, 40, 60],
#  'Lhr': [100, 30, 90],
#  'Isb': [90, 50, 100]}

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print(df.describe())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
print(df.isnull().sum())
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
average_measurements = df.groupby('species').mean()
print(average_measurements)
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

df['C'] = 0

print(df)
# Out:
#    A  B  C
# 0  1  4  0
# 1  2  5  0
# 2  3  6  0
